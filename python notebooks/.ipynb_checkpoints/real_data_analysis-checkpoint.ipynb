# %%
import pandas as pd
from sklearn.calibration import CalibratedClassifierCV, calibration_curve
from matplotlib import pyplot as plt
import os
import numpy as np
import seaborn as sns

# %%
raxml_real_data = pd.read_csv("/Users/noa/Workspace/bootstrap_results/remote_results/real_data_analysis/raxml_real_data.csv")
iqtree_real_data = pd.read_csv("/Users/noa/Workspace/bootstrap_results/remote_results/real_data_analysis/iqtree_real_data.csv")

# %%
#aLRT
sns.regplot(x='predicted_bootstrap_score_nni',y='aLRT_iqtree', data = iqtree_real_data )
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='y = x')

# %%
sns.regplot(y='aBayes_iqtree',x='predicted_bootstrap_score_nni', data = iqtree_real_data)
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='y = x')

# %%
iqtree_real_data['ultrafast_support'] = iqtree_real_data['bootstrap_support']/100
sns.regplot(y='ultrafast_support',x='predicted_bootstrap_score_nni', data = iqtree_real_data)
plt.plot([0, 1], [0, 1], color='red', linestyle='--', label='y = x')

# %%
print(np.mean(iqtree_real_data['aLRT_iqtree']))
print(np.mean(iqtree_real_data['aBayes_iqtree']))
print(np.mean(iqtree_real_data['ultrafast_support']))
print(np.mean(iqtree_real_data['predicted_bootstrap_score_nni']))
print(np.mean(iqtree_real_data['predicted_bootstrap_score_no_nni']))
# Out:
# 0.9531967213114754
# 0.938890290037831
# 0.9137452711223203
# 0.9394102631843515
# 0.9777017893592013

# %%
sns.regplot(y='predicted_bootstrap_score_nni', x='bootstrap_support', data = raxml_real_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tq/zxd_j92j2dv80nh2m_d741fr0000gn/T/ipykernel_22509/67626939.py in <module>
# ----> 1 plt.regplot(y='predicted_bootstrap_score_nni', x='bootstrap_support', data = raxml_real_data)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'regplot'

# %%
plt.hist(raxml_real_data['predicted_bootstrap_score_nni'], bins=30)
# Out:
# (array([  2.,   1.,   2.,   1.,   3.,   2.,   3.,   4.,   5.,   5.,   3.,
#           5.,   7.,   4.,   8.,   8.,   5.,   9.,   8.,   9.,   7.,   7.,
#           8.,  10.,  16.,  12.,  19.,  20.,  33., 567.]),
#  array([0.02944759, 0.06179934, 0.09415109, 0.12650284, 0.15885458,
#         0.19120633, 0.22355808, 0.25590982, 0.28826157, 0.32061332,
#         0.35296506, 0.38531681, 0.41766856, 0.4500203 , 0.48237205,
#         0.5147238 , 0.54707554, 0.57942729, 0.61177904, 0.64413078,
#         0.67648253, 0.70883428, 0.74118603, 0.77353777, 0.80588952,
#         0.83824127, 0.87059301, 0.90294476, 0.93529651, 0.96764825,
#         1.        ]),
#  <BarContainer object of 30 artists>)

# %%
print(np.mean(raxml_real_data['bootstrap_support']))
print(np.mean(raxml_real_data['tbe_raxml']))
print(np.mean(raxml_real_data['predicted_bootstrap_score_nni']))
# Out:
# 73.2219419924338
# 0.8648210138713744
# 0.9097717036119181

# %%
np.corrcoef(raxml_real_data["predicted_bootstrap_score_nni"],raxml_real_data["bootstrap_support"])
# Out:
# array([[1.        , 0.73441065],
#        [0.73441065, 1.        ]])
